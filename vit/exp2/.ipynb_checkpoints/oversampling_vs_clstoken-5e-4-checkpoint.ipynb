# %%
from pickle import load
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
configs, losses_accs_ = load(open('train_bootstrap_vs_clstoken-5e-4.pickle', 'rb'))

# %%
losses_accs_df = list(map(lambda x: pd.DataFrame(x), losses_accs_))

# %%
for i in list(range(len(configs)))[::2]:
    plt.plot(losses_accs_df[i]['val_acc'], color="blue")
    plt.plot(losses_accs_df[i]['test_acc'], color="blue", label=f"class_token: {configs[i]['use_cls_token']}")
    plt.plot(losses_accs_df[i+1]['val_acc'], color="red")
    plt.plot(losses_accs_df[i+1]['test_acc'], color="red",  label=f"class_token: {configs[i+1]['use_cls_token']}")
    plt.grid()
    plt.legend()
    plt.title(configs[i])
    plt.ylim([.5, 1])
    plt.show()

# %%
[(','.join([f'{k}:{v}' for (k, v) in config.items()]), (losses_accs.val_loss.min(), losses_accs.val_loss.argmin()), losses_accs.val_acc[losses_accs.val_loss.argmin()], losses_accs.test_acc[losses_accs.val_loss.argmin()]) for config, losses_accs in zip(configs, losses_accs_df)]
# Out:
# [('n_sessions:1,bootstrap:1_each-epoch,use_cls_token:False,epochs:30',
#   (1.0850379109382629, 20),
#   0.8069828748703003,
#   0.6520887017250061),
#  ('n_sessions:1,bootstrap:1_each-epoch,use_cls_token:True,epochs:30',
#   (0.9872451364994049, 14),
#   0.7953447699546814,
#   0.6366168260574341),
#  ('n_sessions:1,bootstrap:no,use_cls_token:False,epochs:100',
#   (0.8925487875938416, 93),
#   0.7872200012207031,
#   0.6040226817131042),
#  ('n_sessions:1,bootstrap:no,use_cls_token:True,epochs:100',
#   (0.6112297713756562, 72),
#   0.8328941464424133,
#   0.6449716091156006),
#  ('n_sessions:5,bootstrap:1_each-epoch,use_cls_token:False,epochs:30',
#   (0.9407918155193329, 25),
#   0.7630792856216431,
#   0.7599015235900879),
#  ('n_sessions:5,bootstrap:1_each-epoch,use_cls_token:True,epochs:30',
#   (0.854101810766303, 12),
#   0.7339336276054382,
#   0.7524112462997437),
#  ('n_sessions:5,bootstrap:no,use_cls_token:False,epochs:100',
#   (0.7637861798638883, 67),
#   0.7533498406410217,
#   0.7684178352355957),
#  ('n_sessions:5,bootstrap:no,use_cls_token:True,epochs:100',
#   (0.7572432704593824, 70),
#   0.7689254879951477,
#   0.7789862751960754)]

# %%
[(','.join([f'{k}:{v}' for (k, v) in config.items()]), losses_accs.val_acc[22], losses_accs.test_acc[22]) for config, losses_accs in zip(configs, losses_accs_df)]
# Out:
# [('n_sessions:1,bootstrap:1_each-epoch,use_cls_token:False,epochs:30',
#   0.8032498955726624,
#   0.635894775390625),
#  ('n_sessions:1,bootstrap:1_each-epoch,use_cls_token:True,epochs:30',
#   0.8192797303199768,
#   0.6696234941482544),
#  ('n_sessions:1,bootstrap:no,use_cls_token:False,epochs:100',
#   0.561045229434967,
#   0.5138731598854065),
#  ('n_sessions:1,bootstrap:no,use_cls_token:True,epochs:100',
#   0.561045229434967,
#   0.5138731598854065),
#  ('n_sessions:5,bootstrap:1_each-epoch,use_cls_token:False,epochs:30',
#   0.7495519518852234,
#   0.7558998465538025),
#  ('n_sessions:5,bootstrap:1_each-epoch,use_cls_token:True,epochs:30',
#   0.7763506174087524,
#   0.7878103852272034),
#  ('n_sessions:5,bootstrap:no,use_cls_token:False,epochs:100',
#   0.5543227791786194,
#   0.4914836883544922),
#  ('n_sessions:5,bootstrap:no,use_cls_token:True,epochs:100',
#   0.5543227791786194,
#   0.4914836883544922)]

# %%
[(','.join([f'{k}:{v}' for (k, v) in config.items()]), losses_accs.val_acc.argmax(), losses_accs.val_acc[losses_accs.val_acc.argmax()], losses_accs.test_acc[losses_accs.val_acc.argmax()]) for config, losses_accs in zip(configs, losses_accs_df)]
# Out:
# [('n_sessions:1,bootstrap:1_each-epoch,use_cls_token:False,epochs:30',
#   25,
#   0.8199385404586792,
#   0.6712738275527954),
#  ('n_sessions:1,bootstrap:1_each-epoch,use_cls_token:True,epochs:30',
#   26,
#   0.8324549794197083,
#   0.6805570125579834),
#  ('n_sessions:1,bootstrap:no,use_cls_token:False,epochs:100',
#   97,
#   0.8008344173431396,
#   0.6202166080474854),
#  ('n_sessions:1,bootstrap:no,use_cls_token:True,epochs:100',
#   70,
#   0.8467281460762024,
#   0.6430118680000305),
#  ('n_sessions:5,bootstrap:1_each-epoch,use_cls_token:False,epochs:30',
#   27,
#   0.775155782699585,
#   0.7788836359977722),
#  ('n_sessions:5,bootstrap:1_each-epoch,use_cls_token:True,epochs:30',
#   29,
#   0.7807886004447937,
#   0.7820644378662109),
#  ('n_sessions:5,bootstrap:no,use_cls_token:False,epochs:100',
#   88,
#   0.761969804763794,
#   0.7666735053062439),
#  ('n_sessions:5,bootstrap:no,use_cls_token:True,epochs:100',
#   82,
#   0.7721259593963623,
#   0.7859634757041931)]

# %%
losses_accs_df = list(map(lambda x: pd.DataFrame(x), losses_accs_))
for config, losses_accs in list(zip(configs, losses_accs_df)):
    plt.plot(losses_accs['train_loss'])
    plt.plot(losses_accs['val_loss'])
    plt.plot(losses_accs['test_loss'])
    plt.grid()
    plt.title(config)
    plt.show()
