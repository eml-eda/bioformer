# %%
from pickle import load

configs, n_params_, losses_accs_ = load(open('results_1623257320.pickle', 'rb'))

import matplotlib.pyplot as plt
import pandas as pd

losses_accs_df = list(map(lambda x: pd.DataFrame(x), losses_accs_))

for config, losses_accs in zip(configs, losses_accs_df):
    
    print("Addestrato su ", config['sessions'], "sessioni con i soggetti", config['subjects'])
    print(config['training_config'])
    #print(config)
    
    fig, ax = plt.subplots(figsize=(12,4), ncols=2)
    ax[0].plot(losses_accs['train_acc'])
    ax[0].plot(losses_accs['val_acc'])
    ax[0].plot(losses_accs['test_acc'])
    ax[0].set_ylim([.5, 1.])
    
    ax[1].plot(losses_accs['train_loss'])
    ax[1].plot(losses_accs['val_loss'])
    ax[1].plot(losses_accs['test_loss'])
    ax[1].set_ylim([0, 4])
    
    ax[0].grid()
    ax[1].grid()
    
    plt.show()
# Out:
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 600, 'batch_size': 1024, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.001, 'step_size_up': 300, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 1200, 'batch_size': 1024, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.001, 'step_size_up': 600, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 300, 'batch_size': 256, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.001, 'step_size_up': 150, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 600, 'batch_size': 256, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.001, 'step_size_up': 300, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 1200, 'batch_size': 256, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.001, 'step_size_up': 600, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 300, 'batch_size': 1024, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.001, 'step_size_up': 150, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}

# %%
from pickle import load

configs, n_params_, losses_accs_ = load(open('results_1623262356.pickle', 'rb'))

import matplotlib.pyplot as plt
import pandas as pd

losses_accs_df = list(map(lambda x: pd.DataFrame(x), losses_accs_))

for config, losses_accs in zip(configs, losses_accs_df):
    
    print("Addestrato su ", config['sessions'], "sessioni con i soggetti", config['subjects'])
    print(config['training_config'])
    #print(config)
    
    fig, ax = plt.subplots(figsize=(12,4), ncols=2)
    ax[0].plot(losses_accs['train_acc'])
    ax[0].plot(losses_accs['val_acc'])
    ax[0].plot(losses_accs['test_acc'])
    ax[0].set_ylim([.5, 1.])
    
    ax[1].plot(losses_accs['train_loss'])
    ax[1].plot(losses_accs['val_loss'])
    ax[1].plot(losses_accs['test_loss'])
    ax[1].set_ylim([0, 4])
    
    ax[0].grid()
    ax[1].grid()
    
    plt.show()
# Out:
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 600, 'batch_size': 1024, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 300, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 1200, 'batch_size': 1024, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 600, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 300, 'batch_size': 256, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 150, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 600, 'batch_size': 256, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 300, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 1200, 'batch_size': 256, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 600, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  1 sessioni con i soggetti (5,)
# {'epochs': 300, 'batch_size': 1024, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 150, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}

# %%
from pickle import load

configs, n_params_, losses_accs_ = load(open('results_1623271797.pickle', 'rb'))

import matplotlib.pyplot as plt
import pandas as pd

losses_accs_df = list(map(lambda x: pd.DataFrame(x), losses_accs_))

for config, losses_accs in zip(configs, losses_accs_df):
    
    print("Addestrato su ", config['sessions'], "sessioni con i soggetti", config['subjects'])
    print(config['training_config'])
    #print(config)
    
    fig, ax = plt.subplots(figsize=(12,4), ncols=2)
    ax[0].plot(losses_accs['train_acc'])
    ax[0].plot(losses_accs['val_acc'])
    ax[0].plot(losses_accs['test_acc'])
    ax[0].set_ylim([.5, 1.])
    
    ax[1].plot(losses_accs['train_loss'])
    ax[1].plot(losses_accs['val_loss'])
    ax[1].plot(losses_accs['test_loss'])
    ax[1].set_ylim([0, 4])
    
    ax[0].grid()
    ax[1].grid()
    
    plt.show()
# Out:
# Addestrato su  5 sessioni con i soggetti (5,)
# {'epochs': 600, 'batch_size': 1024, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 300, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  5 sessioni con i soggetti (5,)
# {'epochs': 1200, 'batch_size': 1024, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 600, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  5 sessioni con i soggetti (5,)
# {'epochs': 300, 'batch_size': 256, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 150, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  5 sessioni con i soggetti (5,)
# {'epochs': 600, 'batch_size': 256, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 300, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  5 sessioni con i soggetti (5,)
# {'epochs': 1200, 'batch_size': 256, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 600, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
# Addestrato su  5 sessioni con i soggetti (5,)
# {'epochs': 300, 'batch_size': 1024, 'optim': 'Adam', 'optim_hparams': {'lr': 0, 'betas': (0.9, 0.999), 'weight_decay': 0}, 'lr_scheduler': 'CyclicLR', 'lr_scheduler_hparams': {'base_lr': 1e-07, 'max_lr': 0.0001, 'step_size_up': 150, 'step_size_down': None, 'mode': 'triangular', 'cycle_momentum': False}}
